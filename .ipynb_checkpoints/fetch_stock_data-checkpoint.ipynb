# %%
import pandas as pd
import yfinance as yf
import os

url = "https://archives.nseindia.com/content/equities/EQUITY_L.csv"
df = pd.read_csv(url)


symbols = (df["SYMBOL"].head(100) + ".NS").tolist()


folder_name = "data"
os.makedirs(folder_name, exist_ok=True)

for symbol in symbols:

    print(f"Downloading {symbol}...")

  
    stock_data = yf.download(
        symbol,
        period="1y",
        interval="1d",
        auto_adjust=True
    )

  
    file_path = os.path.join(folder_name, f"{symbol}.csv")

 
    stock_data.to_csv(file_path)

    print(f"Saved: {file_path}")

print("\nAll individual CSV files downloaded successfully.")
# Out:
# Downloading 20MICRONS.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\20MICRONS.NS.csv
# Downloading 21STCENMGM.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\21STCENMGM.NS.csv
# Downloading 360ONE.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\360ONE.NS.csv
# Downloading 3BBLACKBIO.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\3BBLACKBIO.NS.csv
# Downloading 3IINFOLTD.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\3IINFOLTD.NS.csv
# Downloading 3MINDIA.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\3MINDIA.NS.csv
# Downloading 3PLAND.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\3PLAND.NS.csv
# Downloading 5PAISA.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\5PAISA.NS.csv
# Downloading 63MOONS.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\63MOONS.NS.csv
# Downloading A2ZINFRA.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\A2ZINFRA.NS.csv
# Downloading AAATECH.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AAATECH.NS.csv
# Downloading AADHARHFC.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AADHARHFC.NS.csv
# Downloading AAKASH.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AAKASH.NS.csv
# Downloading AAREYDRUGS.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AAREYDRUGS.NS.csv
# Downloading AARNAV.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AARNAV.NS.csv
# Downloading AARON.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AARON.NS.csv
# Downloading AARTECH.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AARTECH.NS.csv
# Downloading AARTIDRUGS.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AARTIDRUGS.NS.csv
# Downloading AARTIIND.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AARTIIND.NS.csv
# Downloading AARTIPHARM.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AARTIPHARM.NS.csv
# Downloading AARTISURF.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AARTISURF.NS.csv
# Downloading AARVI.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AARVI.NS.csv
# Downloading AAVAS.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AAVAS.NS.csv
# Downloading ABANSENT.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ABANSENT.NS.csv
# Downloading ABB.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ABB.NS.csv
# Downloading ABBOTINDIA.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ABBOTINDIA.NS.csv
# Downloading ABCAPITAL.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ABCAPITAL.NS.csv
# Downloading ABCOTS.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ABCOTS.NS.csv
# Downloading ABDL.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ABDL.NS.csv
# Downloading ABFRL.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ABFRL.NS.csv
# Downloading ABINFRA.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ABINFRA.NS.csv
# Downloading ABLBL.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ABLBL.NS.csv
# Downloading ABMINTLLTD.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ABMINTLLTD.NS.csv
# Downloading ABMKNO.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ABMKNO.NS.csv
# Downloading ABREL.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ABREL.NS.csv
# Downloading ABSLAMC.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ABSLAMC.NS.csv
# Downloading ACC.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ACC.NS.csv
# Downloading ACCELYA.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ACCELYA.NS.csv
# Downloading ACCURACY.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ACCURACY.NS.csv
# Downloading ACE.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ACE.NS.csv
# Downloading ACEINTEG.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ACEINTEG.NS.csv
# Downloading ACI.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ACI.NS.csv
# Downloading ACL.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ACL.NS.csv
# Downloading ACMESOLAR.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ACMESOLAR.NS.csv
# Downloading ACSTECH.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ACSTECH.NS.csv
# Downloading ACUTAAS.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ACUTAAS.NS.csv
# Downloading ADANIENSOL.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ADANIENSOL.NS.csv
# Downloading ADANIENT.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ADANIENT.NS.csv
# Downloading ADANIGREEN.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ADANIGREEN.NS.csv
# Downloading ADANIPORTS.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ADANIPORTS.NS.csv
# Downloading ADANIPOWER.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ADANIPOWER.NS.csv
# Downloading ADFFOODS.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ADFFOODS.NS.csv
# Downloading ADL.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ADL.NS.csv
# Downloading ADOR.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ADOR.NS.csv
# Downloading ADROITINFO.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ADROITINFO.NS.csv
# Downloading ADSL.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ADSL.NS.csv
# Downloading ADVAIT.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ADVAIT.NS.csv
# Downloading ADVANCE.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ADVANCE.NS.csv
# Downloading ADVANIHOTR.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ADVANIHOTR.NS.csv
# Downloading ADVENTHTL.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ADVENTHTL.NS.csv
# Downloading ADVENZYMES.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\ADVENZYMES.NS.csv
# Downloading AEGISLOG.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AEGISLOG.NS.csv
# Downloading AEGISVOPAK.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AEGISVOPAK.NS.csv
# Downloading AEPL.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AEPL.NS.csv
# Downloading AEQUS.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AEQUS.NS.csv
# Downloading AEROENTER.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AEROENTER.NS.csv
# Downloading AEROFLEX.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AEROFLEX.NS.csv
# Downloading AERONEU.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AERONEU.NS.csv
# Downloading AETHER.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AETHER.NS.csv
# Downloading AFCONS.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AFCONS.NS.csv
# Downloading AFFLE.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AFFLE.NS.csv
# Downloading AFFORDABLE.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AFFORDABLE.NS.csv
# Downloading AFIL.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AFIL.NS.csv
# Downloading AFSL.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AFSL.NS.csv
# Downloading AGARIND.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AGARIND.NS.csv
# Downloading AGARWALEYE.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AGARWALEYE.NS.csv
# Downloading AGI.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AGI.NS.csv
# Downloading AGIIL.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AGIIL.NS.csv
# Downloading AGRITECH.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AGRITECH.NS.csv
# Downloading AGROPHOS.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AGROPHOS.NS.csv
# Downloading AHCL.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AHCL.NS.csv
# Downloading AHLADA.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AHLADA.NS.csv
# Downloading AHLEAST.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AHLEAST.NS.csv
# Downloading AHLUCONT.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AHLUCONT.NS.csv
# Downloading AHLWEST.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AHLWEST.NS.csv
# Downloading AIAENG.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AIAENG.NS.csv
# Downloading AIIL.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AIIL.NS.csv
# Downloading AIRAN.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AIRAN.NS.csv
# Downloading AIROLAM.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AIROLAM.NS.csv
# Downloading AJANTPHARM.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AJANTPHARM.NS.csv
# Downloading AJAXENGG.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AJAXENGG.NS.csv
# Downloading AJMERA.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AJMERA.NS.csv
# Downloading AJOONI.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AJOONI.NS.csv
# Downloading AKASH.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AKASH.NS.csv
# Downloading AKCAPIT.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AKCAPIT.NS.csv
# Downloading AKG.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AKG.NS.csv
# Downloading AKI.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AKI.NS.csv
# Downloading AKSHAR.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AKSHAR.NS.csv
# Downloading AKSHARCHEM.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AKSHARCHEM.NS.csv
# Downloading AKSHOPTFBR.NS...
# [*********************100%***********************]  1 of 1 completed
# Saved: data\AKSHOPTFBR.NS.csv
#
# All individual CSV files downloaded successfully.
